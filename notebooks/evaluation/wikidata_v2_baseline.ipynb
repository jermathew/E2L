# %% [markdown]
# # Build TF-IDF based baseline

# %%
import os
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

# %%
version = 'v2'

# %%
root_dir = '../..'
data_dir = 'data'
corpus_dir = 'corpus'
terms_dir = 'terms'
filename = f'wikidata_corpus_{version}.xlsx'
filepath = os.path.join(root_dir, data_dir, corpus_dir, filename)

# %%
#A = pd.read_excel(data, index_col=0)
A = pd.read_excel(filepath, index_col=0)

# %%
A.head()
# Out:
#    doc_id                                          chunk_doc  label
# 0       0                      stockholm city capital sweden  Q1754
# 1       1                   stockholm capital capital sweden  Q1754
# 2       2  sthlm city city stretches across fourteen_isla...  Q1754
# 3       3  sthlm capital city stretches across fourteen_i...  Q1754
# 4       4  stockholm big city hosts annual nobel prize ce...  Q1754

# %%
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
pseudo_docs = defaultdict(lambda: "")
for i, doc in A.iterrows():
    pseudo_docs[doc.label] += " " + doc.chunk_doc

# %%
entities = list(pseudo_docs.keys())
pdocs = [pseudo_docs[k] for k in entities]

# %%
vectorizer = TfidfVectorizer(min_df=1)
X = vectorizer.fit_transform(pdocs).toarray()

# %%
ranking = {}
features = vectorizer.get_feature_names()
for i, entity in enumerate(entities):
    rank = [(features[i], x) for i, x in sorted(enumerate(X[i]), key=lambda z: -z[1])]
    ranking[entity] = rank

# %%
for entity in entities:
    print(entity)
    for word, w in ranking[entity][:5]:
        print(word, round(w, 2))
    print()
# Out:
# Q1754
# stockholm 0.58
# sthlm 0.37
# city 0.3
# sweden 0.27
# capital 0.15
#
# Q1787199
# stockholm 0.53
# town 0.4
# dakota 0.4
# states 0.34
# united 0.34
#
# Q976601
# wisconsin 0.71
# village 0.5
# stockholm 0.4
# pepin 0.17
# 66 0.13
#
# Q1484620
# asteroid 0.64
# stockholm 0.58
# 10552 0.5
# 00 0.0
# 000 0.0
#
# Q3447382
# stockholm 0.54
# maine 0.52
# town 0.42
# states 0.3
# united 0.29
#
# Q30599096
# film 0.63
# stockholm 0.41
# april 0.2
# 2018 0.17
# budreau 0.13
#
# Q906
# čelâbinsk 0.55
# russia 0.34
# chelyabinsk 0.27
# city 0.24
# ural 0.2
#
# Q1482450
# chelyabinsk 0.6
# asteroid 0.48
# 21088 0.31
# 1992 0.2
# 30 0.12
#
# Q5714
# oblast 0.81
# russia 0.4
# chelyabinsk 0.33
# chelyabinskaya 0.08
# federal_subject 0.08
#
# Q1777988
# university 0.76
# ural 0.33
# state 0.25
# chelyabinsk 0.21
# south 0.19
#
# Q4661508
# meteor 0.53
# earth 0.44
# near 0.38
# asteroid 0.29
# chelyabinsk 0.26
#
# Q2332010
# time 0.64
# yekaterinburg 0.35
# utc 0.3
# zone 0.25
# ahead 0.21
#
# Q600277
# tractor_plant 0.51
# chelyabinsk 0.44
# чтз 0.34
# russian 0.23
# abbreviated 0.17
#
# Q894
# samara 0.7
# russia 0.34
# town 0.29
# city 0.27
# volga 0.2
#
# Q475697
# samara_type 0.5
# fruit 0.27
# genus 0.25
# fibrous_papery_tissue 0.23
# flattened_wing 0.23
#
# Q1067027
# 26922 0.63
# asteroid 0.59
# samara 0.51
# 00 0.0
# 000 0.0
#
# Q3946386
# samara 0.66
# female 0.46
# given 0.33
# female_given_name 0.25
# name 0.24
#
# Q3438102
# nicoya 0.47
# sámara 0.43
# costa 0.4
# rica 0.4
# guanacaste 0.3
#
# Q6779
# utc 0.62
# time 0.44
# offset 0.43
# zone 0.29
# 04 0.23
#
# Q3130
# sydney 0.66
# wales 0.35
# australia 0.28
# new 0.25
# south 0.21
#
# Q932261
# sydney 0.54
# nova 0.46
# scotia 0.46
# breton 0.22
# cape 0.2
#
# Q18915128
# unisex 0.59
# given 0.57
# sydney 0.38
# name 0.37
# characters 0.12
#
# Q1075639
# division 0.67
# australian 0.44
# sydney 0.37
# representatives 0.26
# house 0.25
#
# Q383502
# asteroid 0.66
# sydney 0.64
# 15550 0.39
# 00 0.0
# 000 0.0
#
# Q5356001
# sydney 0.49
# wales 0.38
# electoral 0.36
# new 0.27
# district 0.25
#
# Q1055
# hamburg 0.53
# germany 0.4
# federal_state 0.27
# may 0.2
# city 0.18
#
# Q79657
# hamburg 0.54
# arkansas 0.51
# states 0.33
# united 0.33
# ashley 0.25
#
# Q998718
# hamburg 0.49
# iowa 0.43
# states 0.32
# united 0.32
# missouri 0.28
#
# Q742785
# hamburg 0.54
# town 0.48
# states 0.32
# united 0.32
# york 0.31
#
# Q1005682
# minnesota 0.49
# hamburg 0.49
# carver 0.39
# states 0.37
# united 0.36
#
# Q1082931
# jersey 0.5
# hamburg 0.5
# borough 0.4
# new 0.32
# hardyston 0.2
#
# Q1181264
# pennsylvania 0.72
# borough 0.51
# hamburg 0.38
# berks 0.19
# county 0.09
#
# Q220
# rome 0.49
# italy 0.36
# city 0.28
# comune 0.22
# roman 0.21
#
# Q17167
# republic 0.4
# roman 0.37
# bc 0.34
# period 0.21
# 27 0.21
#
# Q6580
# rome 0.61
# georgia 0.53
# county 0.16
# seat 0.15
# states 0.13
#
# Q6586
# rome 0.57
# york 0.42
# new 0.31
# states 0.26
# united 0.26
#
# Q209878
# series 0.65
# television 0.46
# rome 0.39
# roma 0.22
# two 0.14
#
# Q1925709
# rome 0.54
# iowa 0.51
# states 0.4
# united 0.4
# city 0.24
#
# Q1486
# buenos 0.63
# aires 0.53
# argentina 0.2
# autonomous 0.19
# city 0.19
#
# Q44754
# province 0.59
# aires 0.43
# buenos 0.43
# argentina 0.4
# electoral 0.16
#
# Q2101554
# brazil 0.48
# pernambuco 0.48
# aires 0.4
# buenos 0.4
# municipality 0.33
#
# Q2025478
# cauca 0.44
# colombia 0.44
# aires 0.41
# buenos 0.41
# municipality 0.39
#
# Q2669006
# canton 0.55
# costa 0.43
# rica 0.43
# aires 0.36
# buenos 0.36
#
# Q1181355
# asteroid 0.62
# aires 0.47
# buenos 0.47
# 7850 0.42
# 00 0.0
#
# Q10127
# tangerang 0.62
# city 0.24
# indonesia 0.22
# official 0.2
# census 0.19
#
# Q10123
# regency 0.77
# indonesia 0.37
# tangerang 0.32
# ahmed 0.13
# iskandar 0.13
#
# Q3659306
# tangerang 0.64
# indonesia 0.43
# kecamatan 0.28
# subdivision 0.23
# banten 0.22
#
# Q12487146
# railway 0.69
# line 0.41
# duri 0.37
# tangerang 0.35
# indonesia 0.12
#
# Q15051586
# station 0.56
# tangerang 0.56
# railway 0.49
# railway_station 0.19
# commuters 0.1
#
# Q7682892
# club 0.52
# football 0.49
# tangerang 0.46
# wolves 0.41
# association 0.2
#
# Q172
# toronto 0.49
# canada 0.42
# ontario 0.29
# city 0.19
# tier 0.19
#
# Q736775
# ohio 0.66
# toronto 0.42
# states 0.3
# united 0.3
# jefferson 0.27
#
# Q389974
# asteroid 0.72
# toronto 0.54
# 2104 0.23
# karl 0.15
# observatory 0.14
#
# Q1013097
# iowa 0.59
# toronto 0.52
# clinton 0.38
# states 0.19
# united 0.19
#
# Q2666611
# toronto 0.53
# kansas 0.48
# woodson 0.33
# states 0.29
# united 0.29
#
# Q2688228
# dakota 0.53
# toronto 0.52
# town 0.35
# states 0.3
# united 0.3
#
# Q1461
# manila 0.76
# city 0.31
# philippines 0.18
# urbanized 0.13
# highly 0.12
#
# Q79626
# manila 0.51
# arkansas 0.5
# city 0.29
# states 0.28
# united 0.28
#
# Q129960
# utah 0.42
# flaming 0.31
# gorge 0.31
# town 0.31
# manila 0.3
#
# Q6645392
# humboldt 0.44
# manila 0.42
# census 0.36
# designated 0.34
# place 0.34
#
# Q19625339
# 13513 0.62
# asteroid 0.59
# manila 0.48
# manille 0.21
# 00 0.0
#
# Q6797461
# philippine 0.53
# television 0.44
# maynila 0.36
# series 0.34
# anthology 0.23
#
# Q36312
# calgary 0.63
# alberta 0.35
# city 0.3
# canada 0.27
# edmonton 0.14
#
# Q971268
# asteroid 0.67
# calgary 0.57
# 96192 0.48
# 00 0.0
# 000 0.0
#
# Q5019595
# hamlet 0.64
# calgary 0.52
# mull 0.33
# argyll 0.19
# bute 0.19
#
# Q5019630
# alberta 0.58
# calgary 0.43
# provincial 0.31
# electoral 0.24
# provincial_electoral_district 0.24
#
# Q9658
# winter 0.61
# games 0.39
# 1988 0.32
# olympics 0.32
# olympic 0.3
#
# Q2933906
# canada 0.49
# electoral 0.47
# federal 0.46
# calgary 0.46
# district 0.34
#
# Q1352
# chennai 0.56
# city 0.36
# madras 0.28
# indian 0.27
# tamil 0.26
#
# Q502670
# airport 0.62
# chennai 0.56
# international 0.27
# india 0.26
# aerodrome 0.13
#
# Q15116
# district 0.62
# chennai 0.57
# india 0.37
# nadu 0.13
# tamil 0.13
#
# Q1364464
# university 0.65
# madras 0.38
# public 0.37
# india 0.23
# 18_universities 0.09
#
# Q1292535
# team 0.48
# super 0.42
# sports 0.39
# kings 0.33
# chennai 0.32
#
# Q257382
# railway 0.55
# station 0.55
# chennai 0.39
# central 0.29
# terminus 0.17
#
# Q270
# warsaw 0.59
# city 0.36
# capital 0.31
# varsovie 0.26
# varšuva 0.26
#
# Q992560
# warsaw 0.63
# indiana 0.39
# states 0.32
# united 0.32
# 559 0.25
#
# Q1919763
# kentucky 0.53
# warsaw 0.48
# city 0.32
# gallatin 0.25
# states 0.23
#
# Q576165
# warsaw 0.54
# illinois 0.36
# states 0.27
# united 0.27
# city 0.24
#
# Q967161
# warsaw 0.55
# missouri 0.41
# states 0.37
# united 0.37
# 127 0.33
#
# Q1376135
# warsaw 0.55
# town 0.44
# states 0.38
# united 0.37
# virginia 0.3
#
# Q7970879
# warsaw 0.54
# town 0.44
# york 0.36
# new 0.27
# wyoming 0.26
#
# Q3805
# amman 0.87
# city 0.26
# jordan 0.26
# capital 0.2
# millions 0.19
#
# Q116240
# amman 0.48
# human 0.37
# jost 0.37
# 1591 0.2
# printmaker 0.18
#
# Q1200549
# devi 0.55
# mariamman 0.42
# goddess 0.28
# mother 0.28
# indian 0.23
#
# Q115787
# amman 0.48
# johann 0.37
# petersburg 0.26
# human 0.21
# st 0.21
#
# Q16479584
# amman 0.7
# family_name 0.24
# botanist 0.22
# swiss 0.22
# family 0.19
#
# Q4747127
# building 0.72
# amman 0.43
# 1987 0.22
# register 0.22
# listed 0.2
#
# Q3711
# belgrade 0.62
# serbia 0.49
# capital 0.15
# београд 0.14
# serbian 0.13
#
# Q815570
# belgrade 0.68
# states 0.23
# united 0.23
# bozeman 0.2
# mt 0.2
#
# Q581832
# belgrade 0.62
# minnesota 0.36
# states 0.34
# united 0.34
# city 0.28
#
# Q2301099
# belgrade 0.73
# town 0.34
# maine 0.23
# states 0.22
# united 0.22
#
# Q2745909
# village 0.54
# nebraska 0.51
# belgrade 0.41
# nance 0.35
# states 0.22
#
# Q3476260
# unincorporated 0.46
# community 0.42
# missouri 0.36
# belgrade 0.27
# 10_km 0.18
#
# Q2868
# lima 0.57
# kings 0.34
# capital 0.33
# peru 0.31
# city 0.28
#
# Q9927
# letter 0.59
# latin 0.3
# alphabet 0.3
# consonant 0.3
# plural_els 0.3
#
# Q983974
# lima 0.61
# ohio 0.51
# states 0.2
# united 0.2
# statistical 0.17
#
# Q3031413
# lima 0.79
# peru 0.4
# district 0.24
# province 0.17
# cercado 0.09
#
# Q11255517
# lima 0.75
# born 0.35
# brazilian 0.29
# footballer 0.13
# player 0.13
#
# Q1142219
# airport 0.6
# chávez 0.37
# jorge 0.37
# international 0.32
# spjc 0.2
#
# Q374365
# jeddah 0.63
# governorate 0.36
# arabia 0.33
# saudi 0.33
# city 0.19
#
# Q6172687
# horse 0.56
# jeddah 0.5
# 1895 0.16
# 1897 0.16
# 1899 0.16
#
# Q737945
# skyscraper 0.54
# jeddah 0.49
# tower 0.48
# saudi 0.22
# arabia 0.17
#
# Q1151131
# lighthouse 0.65
# jeddah 0.56
# light 0.31
# arabia 0.15
# saudi 0.14
#
# Q722557
# club 0.74
# association 0.45
# football 0.43
# jeddah 0.26
# 00 0.0
#
# Q2267106
# port 0.75
# jeddah 0.4
# islamic 0.28
# saudi 0.26
# arabia 0.23
#
# Q376749
# chittagong 0.47
# bangladesh 0.35
# city 0.34
# southwestern_part 0.3
# country 0.22
#
# Q5102380
# film 0.64
# chittagong 0.5
# 2012 0.15
# bedabrata 0.14
# box 0.14
#
# Q5642461
# bangladesh 0.6
# thana 0.51
# halishahar 0.43
# chittagong 0.31
# estate 0.16
#
# Q158087
# division 0.77
# bangladesh 0.53
# chattogram 0.21
# chittagong 0.19
# bazar 0.06
#
# Q1074991
# district 0.66
# bangladesh 0.52
# chittagong 0.4
# chattogram 0.24
# eastern_region 0.14
#
# Q7895267
# university 0.64
# chittagong 0.43
# public 0.32
# research 0.26
# public_research_university 0.15
#
# Q1874
# odessa 0.58
# ukraine 0.5
# amalgamated 0.22
# оде 0.21
# hromada 0.18
#
# Q128361
# odessa 0.58
# texas 0.51
# ector 0.28
# states 0.24
# united 0.24
#
# Q159658
# secret 0.59
# society 0.55
# odessa 0.46
# nazi 0.26
# network 0.21
#
# Q754420
# odessa 0.48
# town 0.36
# states 0.26
# united 0.26
# castle 0.24
#
# Q149681
# asteroid 0.57
# odessa 0.48
# 2606 0.4
# crimean 0.18
# 1976 0.14
#
# Q2228947
# odessa 0.59
# minnesota 0.52
# states 0.32
# united 0.32
# city 0.28
#
# Q34600
# kyōto 0.41
# kyoto 0.36
# city 0.25
# japan 0.24
# prefecture 0.22
#
# Q153721
# asteroid 0.61
# kyoto 0.58
# 4352 0.54
# 00 0.0
# 000 0.0
#
# Q120730
# prefecture 0.78
# japan 0.37
# kyoto 0.27
# kyōto 0.17
# fu 0.16
#
# Q336264
# university 0.73
# kyoto 0.39
# national 0.25
# japan 0.23
# top 0.16
#
# Q55616335
# album 0.52
# kyoto 0.46
# studio 0.42
# tyga 0.2
# 24hrs 0.15
#
# Q25217466
# kyoto 0.6
# single 0.56
# lean 0.32
# yung 0.27
# production 0.15
#
# Q3692
# riyadh 0.66
# capital 0.21
# ibn 0.21
# saudi 0.21
# ar 0.2
#
# Q1249255
# region 0.69
# riyadh 0.39
# arabia 0.35
# saudi 0.35
# province 0.16
#
# Q1752043
# university 0.66
# saud 0.34
# king 0.32
# riyadh 0.27
# arabia 0.18
#
# Q4118886
# university 0.4
# bint 0.37
# princess 0.32
# abdul 0.27
# nora 0.27
#
# Q3855748
# riyadh 0.47
# metro 0.41
# proposed 0.3
# entity 0.28
# transit 0.21
#
# Q56017387
# eprix 0.5
# diriyah 0.44
# held 0.32
# recurring_sporting_event 0.28
# formula 0.26
#
# Q5112
# adelaide 0.76
# australia 0.21
# city 0.2
# south 0.14
# light 0.13
#
# Q354633
# given 0.46
# adelaide 0.46
# female 0.4
# name 0.39
# heidi 0.2
#
# Q1094063
# adelaide 0.71
# australia 0.41
# local_government_area 0.34
# south 0.24
# local 0.15
#
# Q487990
# 525 0.52
# adelaide 0.41
# asteroid 0.39
# 1930 0.17
# arend 0.17
#
# Q5355018
# adelaide 0.59
# electoral 0.36
# south 0.33
# australia 0.29
# district 0.26
#
# Q2973361
# division 0.39
# adelaide 0.39
# road 0.37
# australian 0.3
# representatives 0.21
#
# Q48278
# medellín 0.49
# colombia 0.46
# department 0.32
# city 0.29
# antioquia 0.29
#
# Q63166816
# song 0.49
# medellín 0.48
# madonna 0.39
# maluma 0.3
# single 0.25
#
# Q28465089
# team 0.57
# continental 0.44
# uci 0.44
# medellín 0.34
# cycling 0.27
#
# Q668384
# spain 0.68
# medellín 0.41
# medellin 0.29
# municipality 0.28
# badajoz 0.16
#
# Q6008533
# medellín 0.61
# de 0.32
# veracruz 0.29
# human 0.29
# settlement 0.28
#
# Q22713116
# asteroid 0.62
# medellín 0.6
# 366272 0.5
# 00 0.0
# 000 0.0
#
# Q570937
# ordos 0.46
# ěrduōsī 0.28
# prefecture 0.28
# city 0.26
# shì 0.24
#
# Q1670841
# desert 0.83
# ordos 0.35
# china 0.13
# steppe_region 0.1
# inner 0.08
#
# Q127455
# culture 0.75
# archaeological 0.41
# ordos 0.35
# bce 0.13
# 6th 0.12
#
# Q3538450
# airport 0.56
# ejin 0.44
# horo 0.44
# ordos 0.31
# zbds 0.16
#
# Q621143
# ordos 0.59
# plateau 0.44
# geographic 0.4
# region 0.27
# gaoyuan 0.16
#
# Q1825597
# track 0.49
# racing 0.44
# auto 0.34
# circuit 0.34
# ordos 0.27
#
# Q3766
# damascus 0.43
# jasmine 0.43
# city 0.38
# sham 0.36
# syria 0.31
#
# Q2199224
# georgia 0.74
# damascus 0.5
# early 0.26
# municipality 0.2
# county 0.16
#
# Q1374077
# damascus 0.48
# town 0.36
# bristol 0.33
# states 0.31
# united 0.31
#
# Q754122
# designated_place 0.61
# census 0.48
# damascus 0.42
# maryland 0.33
# montgomery 0.15
#
# Q3476539
# oregon 0.66
# damascus 0.35
# 2016 0.28
# disincorporated 0.15
# legislature 0.15
#
# Q1955496
# damascus 0.61
# human 0.48
# settlement 0.46
# america 0.19
# states 0.16
#
# Q26590
# juárez 0.67
# ciudad 0.48
# paso 0.19
# border 0.17
# city 0.15
#
# Q2557122
# municipality 0.58
# juárez 0.47
# mexico 0.44
# chihuahua 0.2
# 004 0.11
#
# Q1643457
# juárez 0.56
# municipality 0.51
# mexico 0.44
# town 0.12
# 162 0.11
#
# Q41662326
# juárez 0.67
# born 0.43
# mexican 0.29
# argentine 0.22
# surname 0.2
#
# Q3846448
# mexico 0.56
# municipality 0.54
# hidalgo 0.36
# juárez 0.35
# 1820 0.19
#
# Q5816925
# station 0.56
# guadalajara 0.43
# juarez 0.36
# light 0.24
# underground 0.22
#
# Q4033577
# taxon 0.51
# agra 0.4
# adult 0.2
# beetles 0.2
# predators 0.2
#
# Q39852
# comune 0.64
# italy 0.47
# agra 0.44
# lombardy 0.22
# varese 0.22
#
# Q2827127
# agra 0.59
# kansas 0.5
# states 0.32
# united 0.32
# phillips 0.24
#
# Q519558
# maria 0.42
# agra 0.4
# fátima 0.39
# de 0.28
# paraíba 0.26
#
# Q370523
# agra 0.6
# town 0.48
# states 0.31
# united 0.31
# oklahoma 0.29
#
# Q1849321
# agra 0.47
# airport 0.39
# enclave 0.26
# civil 0.24
# force 0.23
#
# Q3561
# algiers 0.52
# alger 0.52
# algeria 0.41
# city 0.37
# capital 0.26
#
# Q141026
# province 0.57
# algeria 0.53
# algiers 0.38
# alger 0.23
# french 0.12
#
# Q1414527
# film 0.69
# algiers 0.45
# french 0.16
# hiding 0.15
# 1938 0.14
#
# Q4724224
# orleans 0.47
# algiers 0.46
# community 0.38
# neighborhood 0.34
# new 0.27
#
# Q20012828
# algiers 0.52
# musical 0.43
# group 0.35
# band 0.21
# concept 0.14
#
# Q4724226
# album 0.62
# algiers 0.49
# calexico 0.39
# americana 0.18
# indie 0.18
#
# Q8573
# sun 0.51
# human 0.41
# sen 0.31
# yat 0.31
# revolutionary 0.27
#
# Q59223
# zhongshan 0.73
# prefecture 0.26
# city 0.22
# china 0.22
# level 0.2
#
# Q271167
# zhongshan 0.6
# sun 0.38
# district 0.34
# taipei 0.28
# taiwan 0.28
#
# Q699591
# chinese 0.32
# kun 0.31
# cao 0.25
# 1862 0.19
# served 0.19
#
# Q10887841
# yu 0.58
# yue 0.47
# human 0.3
# chinese 0.21
# philosopher 0.19
#
# Q10929492
# china 0.5
# chengguan 0.46
# town 0.36
# qinghai 0.34
# huangyuan 0.19
#
# Q3624
# addis 0.65
# ababa 0.39
# ethiopia 0.3
# abäba 0.21
# finfinne 0.15
#
# Q1238770
# university 0.65
# ababa 0.44
# addis 0.44
# aau 0.32
# ethiopian 0.11
#
# Q44923
# airport 0.55
# ababa 0.37
# addis 0.37
# bole 0.37
# international 0.34
#
# Q352962
# stadium 0.75
# ababa 0.33
# addis 0.33
# football 0.3
# association 0.26
#
# Q20982403
# railway 0.64
# djibouti 0.48
# line 0.31
# ababa 0.29
# addis 0.29
#
# Q16250141
# rail 0.59
# light 0.57
# ababa 0.32
# addis 0.32
# railways 0.15
#
# Q200713
# aurangabad 0.73
# maharashtra 0.42
# city 0.26
# hyderabad 0.15
# delhi 0.14
#
# Q590550
# aurangabad 0.56
# human 0.35
# settlement 0.34
# 102 0.29
# 244 0.29
#
# Q2903059
# airport 0.56
# aurangabad 0.54
# india 0.26
# vaau 0.21
# km 0.18
#
# Q4822111
# lok 0.57
# sabha 0.57
# constituency 0.43
# aurangabad 0.23
# bihar 0.15
#
# Q1924611
# aurangabad 0.44
# murshidabad 0.31
# bengal 0.29
# town 0.28
# cd 0.25
#
# Q584916
# aurangabad 0.58
# human 0.45
# settlement 0.44
# nagar_panchayat 0.23
# rapidly 0.23
#
# Q34932
# brisbane 0.7
# queensland 0.47
# australia 0.28
# city 0.26
# capital 0.13
#
# Q917671
# brisbane 0.58
# san 0.39
# francisco 0.24
# states 0.22
# city 0.22
#
# Q917665
# division 0.68
# australian 0.42
# brisbane 0.39
# representatives 0.25
# house 0.23
#
# Q647093
# asteroid 0.66
# brisbane 0.58
# 5277 0.49
# 00 0.0
# 000 0.0
#
# Q4968562
# wales 0.53
# brisbane 0.42
# new 0.38
# south 0.35
# county 0.35
#
# Q917658
# crater 0.75
# impact 0.42
# brisbane 0.35
# lunar 0.24
# circular 0.06

# %% [markdown]
# ---
# ## Save ranking to a file

# %%
df_list = []
for entity, terms_tfidf in ranking.items():
    df_list.append(pd.DataFrame({'label': [entity]*len(terms_tfidf), 
                                 'term': [term for term, _ in terms_tfidf]}))

# %%
df = pd.concat(df_list, axis=0)
df.head()
# Out:
#    label       term
# 0  Q1754  stockholm
# 1  Q1754      sthlm
# 2  Q1754       city
# 3  Q1754     sweden
# 4  Q1754    capital

# %%
df.shape
# Out:
# (895050, 2)

# %%
ranking_filename = f'ranking_wikidata_baseline_{version}.xlsx'
ranking_filepath = os.path.join(root_dir, data_dir, terms_dir, ranking_filename)

# %%
ranking_filepath
# Out:
# '../../data/terms/ranking_wikidata_baseline_v2.xlsx'

# %%
df.to_excel(ranking_filepath)

# %% [markdown]
# ---
